# %%
#hide
# !pip install fastbook fastai ddgs
from fastbook import *
from fastai.vision.widgets import *
from ddgs import DDGS
import warnings
#warnings.filterwarnings("ignore", category=DeprecationWarning)

def search_images_ddgs(keyword):
    images_urls = []
    with DDGS(proxy="tb", timeout=10) as ddgs:
        results = ddgs.images(keyword, max_results=150)
        for r in results:
            images_urls.append(r["image"])
    return images_urls
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 15
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastbook in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (0.0.29)
# Requirement already satisfied: fastai in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (2.8.4)
# Requirement already satisfied: ddgs in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (9.5.4)
# Requirement already satisfied: pip in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (25.2)
# Requirement already satisfied: packaging in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (25.0)
# Requirement already satisfied: graphviz in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (0.21)
# Requirement already satisfied: pandas in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (2.3.2)
# Requirement already satisfied: requests in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (2.32.3)
# Requirement already satisfied: transformers in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (4.56.0)
# Requirement already satisfied: datasets in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (4.0.0)
# Requirement already satisfied: ipywidgets<8 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (7.8.5)
# Requirement already satisfied: sentencepiece in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastbook) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (0.2.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.10 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (9.4.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipywidgets<8->fastbook) (1.1.11)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (7.4.5)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (1.8.8)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (0.23.0)
# Requirement already satisfied: matplotlib in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (3.10.6)
# Requirement already satisfied: pyyaml in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (6.0.2)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (11.3.0)
# Requirement already satisfied: scikit-learn in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (1.7.1)
# Requirement already satisfied: scipy in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (1.16.1)
# Requirement already satisfied: spacy<4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (3.8.7)
# Requirement already satisfied: plum-dispatch in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (2.5.7)
# Requirement already satisfied: cloudpickle in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (3.1.1)
# Requirement already satisfied: torch<2.9,>=1.10 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fastai) (2.8.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (0.17.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (2.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (80.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from spacy<4->fastai) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from requests->fastbook) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from requests->fastbook) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from requests->fastbook) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from requests->fastbook) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: filelock in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from torch<2.9,>=1.10->fastai) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from torch<2.9,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from torch<2.9,>=1.10->fastai) (3.5)
# Requirement already satisfied: fsspec in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from torch<2.9,>=1.10->fastai) (2025.3.0)
# Requirement already satisfied: colorama in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai) (1.17.3)
# Requirement already satisfied: primp>=0.15.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=6.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ddgs) (6.0.1)
# Requirement already satisfied: decorator in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (4.4.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (27.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.2.6)
# Requirement already satisfied: babel>=2.10 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (4.25.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (25.1.0)
# Requirement already satisfied: httpcore==1.* in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.16.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.8.15)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (7.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jinja2->spacy<4->fastai) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.21.1)
# Requirement already satisfied: six>=1.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch<2.9,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.7)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from datasets->fastbook) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from datasets->fastbook) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from datasets->fastbook) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from datasets->fastbook) (0.70.16)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from datasets->fastbook) (0.34.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->fastbook) (1.20.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8->fastbook) (2.9.0.20250708)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from matplotlib->fastai) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from matplotlib->fastai) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from matplotlib->fastai) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from matplotlib->fastai) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pandas->fastbook) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from pandas->fastbook) (2024.2)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from plum-dispatch->fastai) (0.21.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from scikit-learn->fastai) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from scikit-learn->fastai) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from transformers->fastbook) (2025.8.29)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from transformers->fastbook) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tv3ra\appdata\roaming\python\python312\site-packages (from transformers->fastbook) (0.6.2)

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_ddgs(f'{o} bear')
        download_images(dest, urls=results)

# %%
fns = get_image_files(path)
failed = verify_images(fns)
failed.map(Path.unlink)
# Out:
# (#0) []

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\tv3ra/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:04<00:00, 10.5MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.428010</td>
#       <td>0.103527</td>
#       <td>0.011628</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\tv3ra\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.181226</td>
#       <td>0.042579</td>
#       <td>0.011628</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.123251</td>
#       <td>0.026030</td>
#       <td>0.023256</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087136</td>
#       <td>0.014649</td>
#       <td>0.000000</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.069910</td>
#       <td>0.008542</td>
#       <td>0.000000</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(5, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# C:\Users\tv3ra\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <PIL.Image.Image image mode=RGBA size=167x128>
# <PIL.Image.Image image mode=RGBA size=94x128>
# <PIL.Image.Image image mode=RGBA size=188x128>
# <PIL.Image.Image image mode=RGBA size=160x128>
# <PIL.Image.Image image mode=RGBA size=169x128>
# <PIL.Image.Image image mode=RGBA size=244x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=191x128>
# <PIL.Image.Image image mode=RGBA size=228x128>
# <PIL.Image.Image image mode=RGBA size=85x128>
# <PIL.Image.Image image mode=RGBA size=191x128>
# <PIL.Image.Image image mode=RGBA size=167x128>
# <PIL.Image.Image image mode=RGBA size=226x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=168x128>
# <PIL.Image.Image image mode=RGBA size=160x128>
# <PIL.Image.Image image mode=RGBA size=171x128>
# <PIL.Image.Image image mode=RGBA size=160x128>
# <PIL.Image.Image image mode=RGBA size=228x128>
# <PIL.Image.Image image mode=RGBA size=226x128>
# <PIL.Image.Image image mode=RGBA size=96x128>
# <PIL.Image.Image image mode=RGBA size=185x128>
# <PIL.Image.Image image mode=RGBA size=168x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# <PIL.Image.Image image mode=RGBA size=192x128>
# VBox(children=(Dropdown(options=('black', 'grizzly', 'teddy'), value='black'), Dropdown(options=('Train', 'Val…

# %%
cleaner.delete()
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# Out:
# (#0) []

# %%
# Delete images
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# Move images
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export()

# %%
learn_inf = load_learner('export.pkl')
# Out:
# C:\Users\tv3ra\AppData\Roaming\Python\Python312\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %%
btn_upload = widgets.FileUpload()
btn_upload

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: 
    display(img.to_thumb(128,128))
out_pl

#pred,pred_idx,probs = learn_inf.predict(img)

# lbl_pred = widgets.Label()
# lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
# lbl_pred

# %%
btn_run = widgets.Button(description='Classify')
btn_run

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
